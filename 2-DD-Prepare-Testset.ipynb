# %% [markdown]
# <a href="https://colab.research.google.com/github/flavioluizseixas/IA-Materno-Infantil/blob/main/AvaliandoModeloDeepfake.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("reubensuju/celeb-df-v2")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/reubensuju/celeb-df-v2?dataset_version_number=1...
# 100%|██████████| 9.29G/9.29G [05:10<00:00, 32.1MB/s]
# Extracting files...
# Path to dataset files: /home/flavio/.cache/kagglehub/datasets/reubensuju/celeb-df-v2/versions/1

# %%
#!rm -r /root/.cache/kagglehub/datasets/reubensuju/celeb-df-v2/versions/1/Celeb-real/id0_*
#!rm -r /root/.cache/kagglehub/datasets/reubensuju/celeb-df-v2/versions/1/Celeb-real/id1_*
#!rm -r /root/.cache/kagglehub/datasets/reubensuju/celeb-df-v2/versions/1/Celeb-real/id2_*
#!rm -r /root/.cache/kagglehub/datasets/reubensuju/celeb-df-v2/versions/1/Celeb-real/id3_*
#!rm -r /root/.cache/kagglehub/datasets/reubensuju/celeb-df-v2/versions/1/Celeb-synthesis/id0_id1_*
#!rm -r /root/.cache/kagglehub/datasets/reubensuju/celeb-df-v2/versions/1/Celeb-synthesis/id0_id2_*
#!rm -r /root/.cache/kagglehub/datasets/reubensuju/celeb-df-v2/versions/1/Celeb-synthesis/id0_id3_*
#!rm -r /root/.cache/kagglehub/datasets/reubensuju/celeb-df-v2/versions/1/Celeb-synthesis/id0_id4_*
#!rm -r /root/.cache/kagglehub/datasets/reubensuju/celeb-df-v2/versions/1/Celeb-synthesis/id0_id6_*

# !rm -r /home/flavio/.cache/kagglehub/datasets/reubensuju/celeb-df-v2/versions/1/Celeb-real/id0_*
# !rm -r /home/flavio/.cache/kagglehub/datasets/reubensuju/celeb-df-v2/versions/1/Celeb-real/id1_*
# !rm -r /home/flavio/.cache/kagglehub/datasets/reubensuju/celeb-df-v2/versions/1/Celeb-real/id2_*
# !rm -r /home/flavio/.cache/kagglehub/datasets/reubensuju/celeb-df-v2/versions/1/Celeb-real/id3_*
# !rm -r /home/flavio/.cache/kagglehub/datasets/reubensuju/celeb-df-v2/versions/1/Celeb-synthesis/id0_id1_*
# !rm -r /home/flavio/.cache/kagglehub/datasets/reubensuju/celeb-df-v2/versions/1/Celeb-synthesis/id0_id2_*
# !rm -r /home/flavio/.cache/kagglehub/datasets/reubensuju/celeb-df-v2/versions/1/Celeb-synthesis/id0_id3_*
# !rm -r /home/flavio/.cache/kagglehub/datasets/reubensuju/celeb-df-v2/versions/1/Celeb-synthesis/id0_id4_*
# !rm -r /home/flavio/.cache/kagglehub/datasets/reubensuju/celeb-df-v2/versions/1/Celeb-synthesis/id0_id6_*

# %%
import cv2
import torch
import os
import shutil
from facenet_pytorch import MTCNN
from torchvision import transforms
from PIL import Image

# Definir dispositivo
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Inicializar o detector de faces MTCNN
mtcnn = MTCNN(keep_all=True, device=device)

# %%
# Diretórios de entrada e saída
#input_dirs = {
#    "Deepfake": "/root/.cache/kagglehub/datasets/reubensuju/celeb-df-v2/versions/1/Celeb-synthesis",
#    "Real": "/root/.cache/kagglehub/datasets/reubensuju/celeb-df-v2/versions/1/Celeb-real"
#}

input_dirs = {
    "Deepfake": "/home/flavio/.cache/kagglehub/datasets/reubensuju/celeb-df-v2/versions/1/Celeb-synthesis",
    "Real":     "/home/flavio/.cache/kagglehub/datasets/reubensuju/celeb-df-v2/versions/1/Celeb-real"
}

output_base = "videos-teste/CELEB-DF/faces"

# %%
# Criar diretórios de saída
for category in ["Deepfake", "Real"]:
    output_dir = os.path.join(output_base, category)
    if os.path.exists(output_dir):
        shutil.rmtree(output_dir)  # Remove se já existir
    os.makedirs(output_dir, exist_ok=True)

# %%
# Função para extrair frames do vídeo
def extract_frames(video_path, interval=5):
    cap = cv2.VideoCapture(video_path)
    frames = []
    frame_count = 0

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        if frame_count % interval == 0:
            frames.append((frame, frame_count))
        frame_count += 1

    cap.release()
    return frames

# %%
# Função para detectar e salvar faces
def detect_and_save_faces(frames, video_name, category):
    output_dir = os.path.join(output_base, category, video_name)
    os.makedirs(output_dir, exist_ok=True)

    extracted_faces = 0

    for i, (frame, frame_number) in enumerate(frames):
        image = Image.fromarray(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
        boxes, _ = mtcnn.detect(image)

        if boxes is not None:
            for j, box in enumerate(boxes):
                x1, y1, x2, y2 = map(int, box)
                face = image.crop((x1, y1, x2, y2))

                # Salvar a face extraída
                face_filename = os.path.join(output_dir, f"frame_{frame_number}_face_{j}.jpg")
                face.save(face_filename)
                extracted_faces += 1

    return extracted_faces

# %%
LIMIT = 7500

# Contadores de faces extraídas
face_count = {"Real": 0, "Deepfake": 0}

# Processar todos os vídeos nos diretórios
for category, input_dir in input_dirs.items():
    if face_count[category] >= LIMIT:
        print(f"Limite atingido para a categoria {category}, pulando...")
        continue

    for video_file in os.listdir(input_dir):
        video_path = os.path.join(input_dir, video_file)

        if video_file.endswith(('.mp4', '.avi', '.mov', '.mkv')):  # Filtrar tipos de vídeo
            print(f"Processando {video_file} na categoria {category}...")

            frames = extract_frames(video_path, interval=5)
            extracted_faces = detect_and_save_faces(frames, video_file.split('.')[0], category)

            face_count[category] += extracted_faces

            # Parar se atingir o limite
            if face_count[category] >= LIMIT:
                print(f"Limite de {LIMIT} faces atingido para a categoria {category}. Encerrando processamento dessa categoria.")
                break
# Out:
# Processando id3_id28_0006.mp4 na categoria Deepfake...
# Processando id20_id22_0003.mp4 na categoria Deepfake...
# Processando id1_id23_0004.mp4 na categoria Deepfake...
# Processando id37_id3_0000.mp4 na categoria Deepfake...
# Processando id50_id51_0007.mp4 na categoria Deepfake...
# Processando id1_id21_0002.mp4 na categoria Deepfake...
# Processando id51_id53_0004.mp4 na categoria Deepfake...
# Processando id23_id35_0007.mp4 na categoria Deepfake...
# Processando id51_id55_0002.mp4 na categoria Deepfake...
# Processando id25_id26_0000.mp4 na categoria Deepfake...
# Processando id28_id6_0001.mp4 na categoria Deepfake...
# Processando id0_id26_0005.mp4 na categoria Deepfake...
# Processando id44_id48_0001.mp4 na categoria Deepfake...
# Processando id35_id23_0005.mp4 na categoria Deepfake...
# Processando id42_id41_0002.mp4 na categoria Deepfake...
# Processando id21_id24_0000.mp4 na categoria Deepfake...
# Processando id17_id31_0007.mp4 na categoria Deepfake...
# Processando id3_id4_0008.mp4 na categoria Deepfake...
# Processando id33_id30_0005.mp4 na categoria Deepfake...
# Processando id40_id42_0002.mp4 na categoria Deepfake...
# Processando id28_id0_0005.mp4 na categoria Deepfake...
# Processando id3_id31_0006.mp4 na categoria Deepfake...
# Processando id20_id31_0002.mp4 na categoria Deepfake...
# Processando id2_id23_0002.mp4 na categoria Deepfake...
# Processando id6_id16_0000.mp4 na categoria Deepfake...
# Processando id35_id16_0000.mp4 na categoria Deepfake...
# Processando id3_id26_0004.mp4 na categoria Deepfake...
# Processando id52_id49_0009.mp4 na categoria Deepfake...
# Processando id21_id6_0007.mp4 na categoria Deepfake...
# Processando id29_id21_0004.mp4 na categoria Deepfake...
# Processando id1_id2_0002.mp4 na categoria Deepfake...
# Processando id28_id37_0004.mp4 na categoria Deepfake...
# Processando id20_id38_0006.mp4 na categoria Deepfake...
# Processando id39_id47_0004.mp4 na categoria Deepfake...
# Processando id37_id33_0006.mp4 na categoria Deepfake...
# Processando id45_id42_0008.mp4 na categoria Deepfake...
# Processando id47_id42_0008.mp4 na categoria Deepfake...
# Processando id52_id53_0000.mp4 na categoria Deepfake...
# Processando id4_id3_0002.mp4 na categoria Deepfake...
# Processando id22_id26_0001.mp4 na categoria Deepfake...
# Processando id20_id16_0007.mp4 na categoria Deepfake...
# Processando id53_id51_0009.mp4 na categoria Deepfake...
# Processando id50_id52_0004.mp4 na categoria Deepfake...
# Processando id34_id28_0008.mp4 na categoria Deepfake...
# Processando id49_id51_0002.mp4 na categoria Deepfake...
# Processando id48_id43_0004.mp4 na categoria Deepfake...
# Processando id28_id16_0002.mp4 na categoria Deepfake...
# Processando id7_id11_0007.mp4 na categoria Deepfake...
# Processando id21_id33_0006.mp4 na categoria Deepfake...
# Processando id2_id20_0000.mp4 na categoria Deepfake...
# Processando id57_id53_0002.mp4 na categoria Deepfake...
# Processando id29_id33_0003.mp4 na categoria Deepfake...
# Processando id3_id23_0002.mp4 na categoria Deepfake...
# Processando id17_id31_0006.mp4 na categoria Deepfake...
# Processando id3_id1_0009.mp4 na categoria Deepfake...
# Processando id20_id28_0003.mp4 na categoria Deepfake...
# Processando id43_id39_0005.mp4 na categoria Deepfake...
# Processando id38_id28_0009.mp4 na categoria Deepfake...
# Processando id35_id4_0003.mp4 na categoria Deepfake...
# Processando id30_id29_0007.mp4 na categoria Deepfake...
# Processando id26_id21_0005.mp4 na categoria Deepfake...
# Processando id16_id31_0013.mp4 na categoria Deepfake...
# Processando id17_id28_0002.mp4 na categoria Deepfake...
# Processando id20_id9_0009.mp4 na categoria Deepfake...
# Processando id25_id24_0007.mp4 na categoria Deepfake...
# Processando id23_id32_0001.mp4 na categoria Deepfake...
# Processando id39_id46_0006.mp4 na categoria Deepfake...
# Processando id31_id21_0006.mp4 na categoria Deepfake...
# Processando id55_id52_0008.mp4 na categoria Deepfake...
# Processando id41_id45_0004.mp4 na categoria Deepfake...
# Processando id43_id40_0004.mp4 na categoria Deepfake...
# Processando id17_id0_0009.mp4 na categoria Deepfake...
# Processando id44_id43_0001.mp4 na categoria Deepfake...
# Processando id33_id38_0004.mp4 na categoria Deepfake...
# Processando id2_id20_0003.mp4 na categoria Deepfake...
# Processando id46_id43_0006.mp4 na categoria Deepfake...
# Processando id27_id26_0002.mp4 na categoria Deepfake...
# Processando id39_id42_0002.mp4 na categoria Deepfake...
# Processando id16_id0_0007.mp4 na categoria Deepfake...
# Processando id35_id3_0000.mp4 na categoria Deepfake...
# Processando id16_id21_0002.mp4 na categoria Deepfake...
# Processando id7_id10_0003.mp4 na categoria Deepfake...
# Processando id29_id34_0002.mp4 na categoria Deepfake...
# Processando id21_id16_0007.mp4 na categoria Deepfake...
# Processando id4_id6_0003.mp4 na categoria Deepfake...
# Processando id6_id30_0006.mp4 na categoria Deepfake...
# Processando id35_id21_0003.mp4 na categoria Deepfake...
# Limite de 7500 faces atingido para a categoria Deepfake. Encerrando processamento dessa categoria.
# Processando id42_0001.mp4 na categoria Real...
# Processando id4_0006.mp4 na categoria Real...
# Processando id13_0003.mp4 na categoria Real...
# Processando id35_0005.mp4 na categoria Real...
# Processando id61_0000.mp4 na categoria Real...
# Processando id59_0005.mp4 na categoria Real...
# Processando id52_0004.mp4 na categoria Real...
# Processando id7_0007.mp4 na categoria Real...
# Processando id30_0007.mp4 na categoria Real...
# Processando id6_0009.mp4 na categoria Real...
# Processando id52_0001.mp4 na categoria Real...
# Processando id31_0005.mp4 na categoria Real...
# Processando id23_0000.mp4 na categoria Real...
# Processando id13_0005.mp4 na categoria Real...
# Processando id30_0002.mp4 na categoria Real...
# Processando id5_0004.mp4 na categoria Real...
# Processando id32_0004.mp4 na categoria Real...
# Processando id23_0006.mp4 na categoria Real...
# Processando id28_0008.mp4 na categoria Real...
# Processando id28_0009.mp4 na categoria Real...
# Processando id10_0004.mp4 na categoria Real...
# Processando id29_0007.mp4 na categoria Real...
# Processando id34_0004.mp4 na categoria Real...
# Processando id52_0006.mp4 na categoria Real...
# Processando id11_0007.mp4 na categoria Real...
# Processando id10_0009.mp4 na categoria Real...
# Processando id16_0012.mp4 na categoria Real...
# Processando id31_0002.mp4 na categoria Real...
# Processando id59_0000.mp4 na categoria Real...
# Processando id38_0002.mp4 na categoria Real...
# Processando id53_0000.mp4 na categoria Real...
# Processando id54_0002.mp4 na categoria Real...
# Processando id10_0005.mp4 na categoria Real...
# Processando id32_0000.mp4 na categoria Real...
# Processando id5_0008.mp4 na categoria Real...
# Processando id21_0000.mp4 na categoria Real...
# Processando id27_0000.mp4 na categoria Real...
# Processando id61_0003.mp4 na categoria Real...
# Processando id21_0006.mp4 na categoria Real...
# Processando id22_0007.mp4 na categoria Real...
# Processando id13_0000.mp4 na categoria Real...
# Processando id52_0007.mp4 na categoria Real...
# Processando id57_0008.mp4 na categoria Real...
# Processando id40_0009.mp4 na categoria Real...
# Processando id60_0002.mp4 na categoria Real...
# Processando id28_0003.mp4 na categoria Real...
# Processando id36_0009.mp4 na categoria Real...
# Processando id53_0002.mp4 na categoria Real...
# Processando id59_0006.mp4 na categoria Real...
# Processando id35_0002.mp4 na categoria Real...
# Processando id37_0004.mp4 na categoria Real...
# Processando id42_0000.mp4 na categoria Real...
# Processando id21_0008.mp4 na categoria Real...
# Processando id13_0004.mp4 na categoria Real...
# Processando id4_0003.mp4 na categoria Real...
# Processando id7_0005.mp4 na categoria Real...
# Processando id8_0008.mp4 na categoria Real...
# Processando id49_0008.mp4 na categoria Real...
# Processando id22_0006.mp4 na categoria Real...
# Processando id53_0007.mp4 na categoria Real...
# Processando id39_0009.mp4 na categoria Real...
# Processando id17_0007.mp4 na categoria Real...
# Processando id17_0000.mp4 na categoria Real...
# Processando id38_0003.mp4 na categoria Real...
# Processando id34_0005.mp4 na categoria Real...
# Processando id26_0005.mp4 na categoria Real...
# Processando id42_0003.mp4 na categoria Real...
# Processando id32_0005.mp4 na categoria Real...
# Processando id60_0001.mp4 na categoria Real...
# Processando id54_0008.mp4 na categoria Real...
# Processando id41_0006.mp4 na categoria Real...
# Processando id45_0008.mp4 na categoria Real...
# Processando id16_0004.mp4 na categoria Real...
# Processando id34_0003.mp4 na categoria Real...
# Processando id60_0008.mp4 na categoria Real...
# Processando id25_0000.mp4 na categoria Real...
# Processando id39_0005.mp4 na categoria Real...
# Processando id32_0006.mp4 na categoria Real...
# Processando id29_0003.mp4 na categoria Real...
# Processando id49_0004.mp4 na categoria Real...
# Processando id7_0000.mp4 na categoria Real...
# Processando id47_0003.mp4 na categoria Real...
# Processando id13_0007.mp4 na categoria Real...
# Processando id45_0003.mp4 na categoria Real...
# Processando id29_0006.mp4 na categoria Real...
# Processando id37_0006.mp4 na categoria Real...
# Processando id30_0008.mp4 na categoria Real...
# Limite de 7500 faces atingido para a categoria Real. Encerrando processamento dessa categoria.

# %%
import os
import timm
import torch
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Definir caminho do modelo treinado
MODEL_PATH = "/xception_deepfake.pth"

# Diretórios com as imagens
TEST_DIR = "videos-teste/CELEB-DF/faces"

# %%
# Definir transformação das imagens (mesma usada no treinamento)
transform = transforms.Compose([
    transforms.Resize((299, 299)),  # Xception usa 299x299
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])

# %%
# Carregar dataset de teste
test_dataset = ImageFolder(root=TEST_DIR, transform=transform)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
# Carregar modelo treinado
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = timm.create_model("xception41.tf_in1k", pretrained=False, num_classes=2)
model.load_state_dict(torch.load(MODEL_PATH, map_location=device))
model.to(device)
model.eval()
# Out:
# XceptionAligned(
#   (stem): Sequential(
#     (0): ConvNormAct(
#       (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNormAct2d(
#         32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#         (drop): Identity()
#         (act): ReLU(inplace=True)
#       )
#     )
#     (1): ConvNormAct(
#       (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNormAct2d(
#         64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#         (drop): Identity()
#         (act): ReLU(inplace=True)
#       )
#     )
#   )
#   (blocks): Sequential(
#     (0): XceptionModule(
#       (shortcut): ConvNormAct(
#         (conv): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (bn): BatchNormAct2d(
#           128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#       )
#       (stack): Sequential(
#         (act1): ReLU()
#         (conv1): SeparableConv2d(
#           (conv_dw): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#           (bn_dw): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_dw): Identity()
#           (conv_pw): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn_pw): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_pw): Identity()
#         )
#         (act2): ReLU(inplace=True)
#         (conv2): SeparableConv2d(
#           (conv_dw): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#           (bn_dw): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_dw): Identity()
#           (conv_pw): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn_pw): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_pw): Identity()
#         )
#         (act3): ReLU(inplace=True)
#         (conv3): SeparableConv2d(
#           (conv_dw): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=128, bias=False)
#           (bn_dw): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_dw): Identity()
#           (conv_pw): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn_pw): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_pw): Identity()
#         )
#       )
#     )
#     (1): XceptionModule(
#       (shortcut): ConvNormAct(
#         (conv): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (bn): BatchNormAct2d(
#           256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#       )
#       (stack): Sequential(
#         (act1): ReLU()
#         (conv1): SeparableConv2d(
#           (conv_dw): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#           (bn_dw): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_dw): Identity()
#           (conv_pw): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn_pw): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_pw): Identity()
#         )
#         (act2): ReLU(inplace=True)
#         (conv2): SeparableConv2d(
#           (conv_dw): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#           (bn_dw): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_dw): Identity()
#           (conv_pw): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn_pw): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_pw): Identity()
#         )
#         (act3): ReLU(inplace=True)
#         (conv3): SeparableConv2d(
#           (conv_dw): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=256, bias=False)
#           (bn_dw): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_dw): Identity()
#           (conv_pw): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn_pw): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_pw): Identity()
#         )
#       )
#     )
#     (2): XceptionModule(
#       (shortcut): ConvNormAct(
#         (conv): Conv2d(256, 728, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (bn): BatchNormAct2d(
#           728, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#       )
#       (stack): Sequential(
#         (act1): ReLU()
#         (conv1): SeparableConv2d(
#           (conv_dw): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#           (bn_dw): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_dw): Identity()
#           (conv_pw): Conv2d(256, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn_pw): BatchNorm2d(728, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_pw): Identity()
#         )
#         (act2): ReLU(inplace=True)
#         (conv2): SeparableConv2d(
#           (conv_dw): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (bn_dw): BatchNorm2d(728, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_dw): Identity()
#           (conv_pw): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn_pw): BatchNorm2d(728, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_pw): Identity()
#         )
#         (act3): ReLU(inplace=True)
#         (conv3): SeparableConv2d(
#           (conv_dw): Conv2d(728, 728, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=728, bias=False)
#           (bn_dw): BatchNorm2d(728, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_dw): Identity()
#           (conv_pw): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn_pw): BatchNorm2d(728, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_pw): Identity()
#         )
#       )
#     )
#     (3): XceptionModule(
#       (stack): Sequential(
#         (act1): ReLU()
#         (conv1): SeparableConv2d(
#           (conv_dw): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (bn_dw): BatchNorm2d(728, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_dw): Identity()
#           (conv_pw): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn_pw): BatchNorm2d(728, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_pw): Identity()
#         )
#         (act2): ReLU(inplace=True)
#         (conv2): SeparableConv2d(
#           (conv_dw): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (bn_dw): BatchNorm2d(728, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_dw): Identity()
#           (conv_pw): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn_pw): BatchNorm2d(728, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_pw): Identity()
#         )
#         (act3): ReLU(inplace=True)
#         (conv3): SeparableConv2d(
#           (conv_dw): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (bn_dw): BatchNorm2d(728, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_dw): Identity()
#           (conv_pw): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn_pw): BatchNorm2d(728, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_pw): Identity()
#         )
#       )
#     )
#     (4): XceptionModule(
#       (stack): Sequential(
#         (act1): ReLU()
#         (conv1): SeparableConv2d(
#           (conv_dw): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (bn_dw): BatchNorm2d(728, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_dw): Identity()
#           (conv_pw): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn_pw): BatchNorm2d(728, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_pw): Identity()
#         )
#         (act2): ReLU(inplace=True)
#         (conv2): SeparableConv2d(
#           (conv_dw): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (bn_dw): BatchNorm2d(728, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_dw): Identity()
#           (conv_pw): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn_pw): BatchNorm2d(728, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_pw): Identity()
#         )
#         (act3): ReLU(inplace=True)
#         (conv3): SeparableConv2d(
#           (conv_dw): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (bn_dw): BatchNorm2d(728, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_dw): Identity()
#           (conv_pw): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn_pw): BatchNorm2d(728, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_pw): Identity()
#         )
#       )
#     )
#     (5): XceptionModule(
#       (stack): Sequential(
#         (act1): ReLU()
#         (conv1): SeparableConv2d(
#           (conv_dw): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (bn_dw): BatchNorm2d(728, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_dw): Identity()
#           (conv_pw): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn_pw): BatchNorm2d(728, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_pw): Identity()
#         )
#         (act2): ReLU(inplace=True)
#         (conv2): SeparableConv2d(
#           (conv_dw): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (bn_dw): BatchNorm2d(728, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_dw): Identity()
#           (conv_pw): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn_pw): BatchNorm2d(728, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_pw): Identity()
#         )
#         (act3): ReLU(inplace=True)
#         (conv3): SeparableConv2d(
#           (conv_dw): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (bn_dw): BatchNorm2d(728, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_dw): Identity()
#           (conv_pw): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn_pw): BatchNorm2d(728, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_pw): Identity()
#         )
#       )
#     )
#     (6): XceptionModule(
#       (stack): Sequential(
#         (act1): ReLU()
#         (conv1): SeparableConv2d(
#           (conv_dw): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (bn_dw): BatchNorm2d(728, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_dw): Identity()
#           (conv_pw): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn_pw): BatchNorm2d(728, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_pw): Identity()
#         )
#         (act2): ReLU(inplace=True)
#         (conv2): SeparableConv2d(
#           (conv_dw): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (bn_dw): BatchNorm2d(728, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_dw): Identity()
#           (conv_pw): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn_pw): BatchNorm2d(728, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_pw): Identity()
#         )
#         (act3): ReLU(inplace=True)
#         (conv3): SeparableConv2d(
#           (conv_dw): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (bn_dw): BatchNorm2d(728, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_dw): Identity()
#           (conv_pw): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn_pw): BatchNorm2d(728, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_pw): Identity()
#         )
#       )
#     )
#     (7): XceptionModule(
#       (stack): Sequential(
#         (act1): ReLU()
#         (conv1): SeparableConv2d(
#           (conv_dw): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (bn_dw): BatchNorm2d(728, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_dw): Identity()
#           (conv_pw): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn_pw): BatchNorm2d(728, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_pw): Identity()
#         )
#         (act2): ReLU(inplace=True)
#         (conv2): SeparableConv2d(
#           (conv_dw): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (bn_dw): BatchNorm2d(728, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_dw): Identity()
#           (conv_pw): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn_pw): BatchNorm2d(728, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_pw): Identity()
#         )
#         (act3): ReLU(inplace=True)
#         (conv3): SeparableConv2d(
#           (conv_dw): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (bn_dw): BatchNorm2d(728, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_dw): Identity()
#           (conv_pw): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn_pw): BatchNorm2d(728, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_pw): Identity()
#         )
#       )
#     )
#     (8): XceptionModule(
#       (stack): Sequential(
#         (act1): ReLU()
#         (conv1): SeparableConv2d(
#           (conv_dw): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (bn_dw): BatchNorm2d(728, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_dw): Identity()
#           (conv_pw): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn_pw): BatchNorm2d(728, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_pw): Identity()
#         )
#         (act2): ReLU(inplace=True)
#         (conv2): SeparableConv2d(
#           (conv_dw): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (bn_dw): BatchNorm2d(728, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_dw): Identity()
#           (conv_pw): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn_pw): BatchNorm2d(728, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_pw): Identity()
#         )
#         (act3): ReLU(inplace=True)
#         (conv3): SeparableConv2d(
#           (conv_dw): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (bn_dw): BatchNorm2d(728, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_dw): Identity()
#           (conv_pw): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn_pw): BatchNorm2d(728, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_pw): Identity()
#         )
#       )
#     )
#     (9): XceptionModule(
#       (stack): Sequential(
#         (act1): ReLU()
#         (conv1): SeparableConv2d(
#           (conv_dw): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (bn_dw): BatchNorm2d(728, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_dw): Identity()
#           (conv_pw): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn_pw): BatchNorm2d(728, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_pw): Identity()
#         )
#         (act2): ReLU(inplace=True)
#         (conv2): SeparableConv2d(
#           (conv_dw): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (bn_dw): BatchNorm2d(728, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_dw): Identity()
#           (conv_pw): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn_pw): BatchNorm2d(728, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_pw): Identity()
#         )
#         (act3): ReLU(inplace=True)
#         (conv3): SeparableConv2d(
#           (conv_dw): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (bn_dw): BatchNorm2d(728, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_dw): Identity()
#           (conv_pw): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn_pw): BatchNorm2d(728, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_pw): Identity()
#         )
#       )
#     )
#     (10): XceptionModule(
#       (stack): Sequential(
#         (act1): ReLU()
#         (conv1): SeparableConv2d(
#           (conv_dw): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (bn_dw): BatchNorm2d(728, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_dw): Identity()
#           (conv_pw): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn_pw): BatchNorm2d(728, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_pw): Identity()
#         )
#         (act2): ReLU(inplace=True)
#         (conv2): SeparableConv2d(
#           (conv_dw): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (bn_dw): BatchNorm2d(728, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_dw): Identity()
#           (conv_pw): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn_pw): BatchNorm2d(728, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_pw): Identity()
#         )
#         (act3): ReLU(inplace=True)
#         (conv3): SeparableConv2d(
#           (conv_dw): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (bn_dw): BatchNorm2d(728, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_dw): Identity()
#           (conv_pw): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn_pw): BatchNorm2d(728, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_pw): Identity()
#         )
#       )
#     )
#     (11): XceptionModule(
#       (shortcut): ConvNormAct(
#         (conv): Conv2d(728, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (bn): BatchNormAct2d(
#           1024, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#       )
#       (stack): Sequential(
#         (act1): ReLU()
#         (conv1): SeparableConv2d(
#           (conv_dw): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (bn_dw): BatchNorm2d(728, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_dw): Identity()
#           (conv_pw): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn_pw): BatchNorm2d(728, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_pw): Identity()
#         )
#         (act2): ReLU(inplace=True)
#         (conv2): SeparableConv2d(
#           (conv_dw): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (bn_dw): BatchNorm2d(728, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_dw): Identity()
#           (conv_pw): Conv2d(728, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn_pw): BatchNorm2d(1024, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_pw): Identity()
#         )
#         (act3): ReLU(inplace=True)
#         (conv3): SeparableConv2d(
#           (conv_dw): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=1024, bias=False)
#           (bn_dw): BatchNorm2d(1024, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_dw): Identity()
#           (conv_pw): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn_pw): BatchNorm2d(1024, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_pw): Identity()
#         )
#       )
#     )
#     (12): XceptionModule(
#       (stack): Sequential(
#         (conv1): SeparableConv2d(
#           (conv_dw): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1024, bias=False)
#           (bn_dw): BatchNorm2d(1024, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_dw): ReLU(inplace=True)
#           (conv_pw): Conv2d(1024, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn_pw): BatchNorm2d(1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_pw): ReLU(inplace=True)
#         )
#         (conv2): SeparableConv2d(
#           (conv_dw): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#           (bn_dw): BatchNorm2d(1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_dw): ReLU(inplace=True)
#           (conv_pw): Conv2d(1536, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn_pw): BatchNorm2d(1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_pw): ReLU(inplace=True)
#         )
#         (conv3): SeparableConv2d(
#           (conv_dw): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#           (bn_dw): BatchNorm2d(1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_dw): ReLU(inplace=True)
#           (conv_pw): Conv2d(1536, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn_pw): BatchNorm2d(2048, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (act_pw): ReLU(inplace=True)
#         )
#       )
#     )
#   )
#   (act): Identity()
#   (head): ClassifierHead(
#     (global_pool): SelectAdaptivePool2d(pool_type=avg, flatten=Flatten(start_dim=1, end_dim=-1))
#     (drop): Dropout(p=0.0, inplace=False)
#     (fc): Linear(in_features=2048, out_features=2, bias=True)
#     (flatten): Identity()
#   )
# )

# %%
# Fazer inferência
all_preds = []
all_labels = []

with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)
        _, preds = torch.max(outputs, 1)

        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

# %%
# Criar matriz de confusão
cm = confusion_matrix(all_labels, all_preds)
labels = ["Real", "Deepfake"]

# Exibir matriz de confusão
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=labels, yticklabels=labels)
plt.xlabel("Predito")
plt.ylabel("Real")
plt.title("Matriz de Confusão")
plt.show()

# Exibir relatório de classificação
print(classification_report(all_labels, all_preds, target_names=labels))
# Out:
#               precision    recall  f1-score   support
#
#         Real       0.77      0.16      0.26      7596
#     Deepfake       0.53      0.95      0.68      7634
#
#     accuracy                           0.56     15230
#    macro avg       0.65      0.56      0.47     15230
# weighted avg       0.65      0.56      0.47     15230
